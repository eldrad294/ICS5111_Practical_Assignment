# %%
# import packages

import pandas as pd
import numpy as np
import json

# Read csv files

user = pd.read_csv('user.csv', header=0, na_filter=False)
business = pd.read_csv('business.csv', header=0, na_filter=False)
review = pd.read_csv('review.csv', header=0, na_filter=False)

# %%
# lat / long binning

business_x = business.latitude
business_y = business.longitude

step = 1

to_bin = lambda x: np.floor(x / step) * step

business["latbin"] = business_x.map(to_bin)
business["lonbin"] = business_y.map(to_bin)


# SQL filtering and joins

business_filtered = business.loc[(business.lonbin == -81) & (business.latbin == 35)];
review_filt = pd.merge(review, business_filtered, left_on='business_id', right_on='id', how='inner');
user_filtered = pd.merge(user, review_filt, left_on='id', right_on='user_id', how='inner');
user_filt = user_filtered.drop_duplicates('id', keep='first');
business_filtered = pd.merge(user_filt, business_filtered, left_on='business_id', right_on='id', how='inner');
business_filt = business_filtered.drop_duplicates('business_id', keep='first');

# Joining from businesses to reviews to users will provide data on users who have commented on businesses from
# a specified location. Further merging in last line is to retrieve additional businesses not located in same geo area.

# %%
business_filtered.T.shape
# Out:
# (57, 77986)

# %%
business_filt.T
# Out:
#                                                                 0      \
# id_x                                           --0RtXvcOIE4XbErYca6Rw
# name_x                                                           Ryan
# review_count_x                                                      2
# yelping_since                                     2013-05-30 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                     4.5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           GJLSZCUg-GInXaitglmXfw
# stars_x                                                             4
# date                                              2013-08-07 00:00:00
# text                Tough to find places around here to eat, so my...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    JJxI7OA8wgr8ZMuwaKborQ
# user_id                                        --0RtXvcOIE4XbErYca6Rw
# id_y                                           JJxI7OA8wgr8ZMuwaKborQ
# name_y                                          Rotisserie Pollo Rico
# neighborhood_x                                               Eastland
# address_x                                           6003 Albemarle Rd
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28212
# latitude_x                                                    35.2035
# longitude_x                                                  -80.7435
# stars_y                                                             4
# review_count_y                                                      4
# is_open_x                                                           0
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           JJxI7OA8wgr8ZMuwaKborQ
# name                                            Rotisserie Pollo Rico
# neighborhood_y                                               Eastland
# address_y                                           6003 Albemarle Rd
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28212
# latitude_y                                                    35.2035
# longitude_y                                                  -80.7435
# stars                                                               4
# review_count                                                        4
# is_open_y                                                           0
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 2      \
# id_x                                           --3WaS23LcIXtxyFULJHTA
# name_x                                                        Kristie
# review_count_x                                                    213
# yelping_since                                     2010-05-02 00:00:00
# useful_x                                                           63
# funny_x                                                             6
# cool_x                                                              2
# fans                                                               10
# average_stars                                                    3.93
# compliment_hot                                                     11
# compliment_more                                                     4
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     5
# compliment_plain                                                   20
# compliment_cool                                                    18
# compliment_funny                                                   18
# compliment_writer                                                   7
# compliment_photos                                                   2
# id_x                                           rsYI3LPC6a7JhjjDYNCTKw
# stars_x                                                             3
# date                                              2016-02-08 00:00:00
# text                We stopped in here for drinks and appetizers o...
# useful_y                                                            1
# funny_y                                                             0
# cool_y                                                              1
# business_id                                    ADgacmZ-qXrSOhMfU6bmTA
# user_id                                        --3WaS23LcIXtxyFULJHTA
# id_y                                           ADgacmZ-qXrSOhMfU6bmTA
# name_y                                                        5Church
# neighborhood_x                                            Fourth Ward
# address_x                                       127 N Tryon St, Ste 8
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28202
# latitude_x                                                    35.2284
# longitude_x                                                  -80.8428
# stars_y                                                           3.5
# review_count_y                                                    507
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           ADgacmZ-qXrSOhMfU6bmTA
# name                                                          5Church
# neighborhood_y                                            Fourth Ward
# address_y                                       127 N Tryon St, Ste 8
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28202
# latitude_y                                                    35.2284
# longitude_y                                                  -80.8428
# stars                                                             3.5
# review_count                                                      507
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 240    \
# id_x                                           --44NNdtngXMzsxyN7ju6Q
# name_x                                                         Austin
# review_count_x                                                      2
# yelping_since                                     2013-01-22 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                       5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     1
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           VCa9DNOwsK24i75S3-mdVA
# stars_x                                                             5
# date                                              2017-07-01 00:00:00
# text                Nate is so kind and caring! He went out of his...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    4l_EtTbBtoxiu-nrYXE34g
# user_id                                        --44NNdtngXMzsxyN7ju6Q
# id_y                                           4l_EtTbBtoxiu-nrYXE34g
# name_y                                                J Wood Flooring
# neighborhood_x
# address_x                                9620 B Pineville Matthews Rd
# city_x                                                      Pineville
# state_x                                                            NC
# postal_code_x                                                   28134
# latitude_x                                                    35.0862
# longitude_x                                                  -80.8807
# stars_y                                                             5
# review_count_y                                                      6
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           4l_EtTbBtoxiu-nrYXE34g
# name                                                  J Wood Flooring
# neighborhood_y
# address_y                                9620 B Pineville Matthews Rd
# city_y                                                      Pineville
# state_y                                                            NC
# postal_code_y                                                   28134
# latitude_y                                                    35.0862
# longitude_y                                                  -80.8807
# stars                                                               5
# review_count                                                        6
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 244    \
# id_x                                           --6D_IuxyKTN53pHi904ag
# name_x                                                           Mary
# review_count_x                                                      2
# yelping_since                                     2013-02-06 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                       5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     1
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           ICRCEntzSM8Hs3ICM4U1wA
# stars_x                                                             5
# date                                              2015-03-19 00:00:00
# text                Best Orthontist in town!  Warm, family friendl...
# useful_y                                                            1
# funny_y                                                             1
# cool_y                                                              0
# business_id                                    O62iMlEE_H8jnAXZqJYiqA
# user_id                                        --6D_IuxyKTN53pHi904ag
# id_y                                           O62iMlEE_H8jnAXZqJYiqA
# name_y                                           Jackson Orthodontics
# neighborhood_x                                           Steele Creek
# address_x                               13527 Steelecroft Pkwy, Ste C
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28278
# latitude_x                                                    35.1024
# longitude_x                                                  -80.9927
# stars_y                                                             5
# review_count_y                                                     11
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           O62iMlEE_H8jnAXZqJYiqA
# name                                             Jackson Orthodontics
# neighborhood_y                                           Steele Creek
# address_y                               13527 Steelecroft Pkwy, Ste C
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28278
# latitude_y                                                    35.1024
# longitude_y                                                  -80.9927
# stars                                                               5
# review_count                                                       11
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 251    \
# id_x                                           --6Ke7_lBBM6XAramtPoWw
# name_x                                                          Laura
# review_count_x                                                     15
# yelping_since                                     2009-09-12 00:00:00
# useful_x                                                           19
# funny_x                                                             1
# cool_x                                                              0
# fans                                                                6
# average_stars                                                    4.41
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           3Nr98kttfdL_l3oTwuUVnw
# stars_x                                                             5
# date                                              2015-06-08 00:00:00
# text                Recently I dined at this restaurant as a guest...
# useful_y                                                            4
# funny_y                                                             2
# cool_y                                                              2
# business_id                                    c-l4nDPZcEwapEiV-Xf08w
# user_id                                        --6Ke7_lBBM6XAramtPoWw
# id_y                                           c-l4nDPZcEwapEiV-Xf08w
# name_y                                                    Ilios Noche
# neighborhood_x
# address_x                                         11508 Providence Rd
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28277
# latitude_x                                                    35.0532
# longitude_x                                                  -80.7704
# stars_y                                                             4
# review_count_y                                                    211
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           c-l4nDPZcEwapEiV-Xf08w
# name                                                      Ilios Noche
# neighborhood_y
# address_y                                         11508 Providence Rd
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28277
# latitude_y                                                    35.0532
# longitude_y                                                  -80.7704
# stars                                                               4
# review_count                                                      211
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 427    \
# id_x                                           --7D3lFxyMYvs2JYiRrg6Q
# name_x                                                           Bill
# review_count_x                                                      2
# yelping_since                                     2016-04-29 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                       5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           UmUSi_7l3Q9u0JTLszH-HQ
# stars_x                                                             5
# date                                              2016-12-04 00:00:00
# text                Very friendly and willing to take the time to ...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    _omO4bgUNP8zQEEyrEsVSw
# user_id                                        --7D3lFxyMYvs2JYiRrg6Q
# id_y                                           _omO4bgUNP8zQEEyrEsVSw
# name_y                                    Killingsworth Environmental
# neighborhood_x
# address_x                                          13216 Albemarle Rd
# city_x                                                      Mint Hill
# state_x                                                            NC
# postal_code_x                                                   28227
# latitude_x                                                    35.2229
# longitude_x                                                  -80.6309
# stars_y                                                             5
# review_count_y                                                      4
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           _omO4bgUNP8zQEEyrEsVSw
# name                                      Killingsworth Environmental
# neighborhood_y
# address_y                                          13216 Albemarle Rd
# city_y                                                      Mint Hill
# state_y                                                            NC
# postal_code_y                                                   28227
# latitude_y                                                    35.2229
# longitude_y                                                  -80.6309
# stars                                                               5
# review_count                                                        4
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 430    \
# id_x                                           --cBKDfZ4AbM9U90VkFyBg
# name_x                                                         Monica
# review_count_x                                                      9
# yelping_since                                     2012-12-26 00:00:00
# useful_x                                                            1
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                    4.56
# compliment_hot                                                      0
# compliment_more                                                     1
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     1
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           XXOOHsiR2O42kmlgJZiSmA
# stars_x                                                             2
# date                                              2014-08-27 00:00:00
# text                I really wanted to love this place...but alas,...
# useful_y                                                            1
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    97K4904NnvB_zSEVGHDc-A
# user_id                                        --cBKDfZ4AbM9U90VkFyBg
# id_y                                           97K4904NnvB_zSEVGHDc-A
# name_y                                                      E Noodles
# neighborhood_x
# address_x                                 360 Exchange St NW, Ste 110
# city_x                                                        Concord
# state_x                                                            NC
# postal_code_x                                                   28027
# latitude_x                                                    35.4157
# longitude_x                                                  -80.6691
# stars_y                                                             4
# review_count_y                                                    120
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           97K4904NnvB_zSEVGHDc-A
# name                                                        E Noodles
# neighborhood_y
# address_y                                 360 Exchange St NW, Ste 110
# city_y                                                        Concord
# state_y                                                            NC
# postal_code_y                                                   28027
# latitude_y                                                    35.4157
# longitude_y                                                  -80.6691
# stars                                                               4
# review_count                                                      120
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 474    \
# id_x                                           --i7WS2pwOQKQl6uB15q1A
# name_x                                                         Pamela
# review_count_x                                                      2
# yelping_since                                     2017-05-06 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                     3.5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           bcdmfvSLh3EGTxq3jvG1hA
# stars_x                                                             5
# date                                              2017-06-07 00:00:00
# text                This Publix has the coldest water fountain. I ...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    oWQaP9yP77B3Au0LAEevdQ
# user_id                                        --i7WS2pwOQKQl6uB15q1A
# id_y                                           oWQaP9yP77B3Au0LAEevdQ
# name_y                                                         Publix
# neighborhood_x                                           Steele Creek
# address_x                                         8120 South Tryon St
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28273
# latitude_x                                                    35.1459
# longitude_x                                                  -80.9295
# stars_y                                                             4
# review_count_y                                                     40
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           oWQaP9yP77B3Au0LAEevdQ
# name                                                           Publix
# neighborhood_y                                           Steele Creek
# address_y                                         8120 South Tryon St
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28273
# latitude_y                                                    35.1459
# longitude_y                                                  -80.9295
# stars                                                               4
# review_count                                                       40
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 479    \
# id_x                                           --JS-RvSykutl1DavCbkIg
# name_x                                                           Mary
# review_count_x                                                      2
# yelping_since                                     2014-07-07 00:00:00
# useful_x                                                            1
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                1
# average_stars                                                       1
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           iWRdm2U3z0NTnbfooFoSzQ
# stars_x                                                             1
# date                                              2016-07-24 00:00:00
# text                TERRIBLE service. DISGUSTING food. I have neve...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    vNllp243LmFMVO0MNyhM1A
# user_id                                        --JS-RvSykutl1DavCbkIg
# id_y                                           vNllp243LmFMVO0MNyhM1A
# name_y                                                    Fox & Hound
# neighborhood_x                                             Ballantyne
# address_x                                     15235 John J Delaney Dr
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28277
# latitude_x                                                     35.054
# longitude_x                                                  -80.8487
# stars_y                                                           2.5
# review_count_y                                                     55
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           vNllp243LmFMVO0MNyhM1A
# name                                                      Fox & Hound
# neighborhood_y                                             Ballantyne
# address_y                                     15235 John J Delaney Dr
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28277
# latitude_y                                                     35.054
# longitude_y                                                  -80.8487
# stars                                                             2.5
# review_count                                                       55
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 492    \
# id_x                                           --LnqQQ2mVdrpPt2UC8d6A
# name_x                                                        Kenneth
# review_count_x                                                      1
# yelping_since                                     2012-04-08 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                       2
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           4zru57Bx5Bi_dbOk3vxcDg
# stars_x                                                             2
# date                                              2014-04-04 00:00:00
# text                Second trip to Groucho's first trip was medioc...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    lCdEv4xr5fOji8C9RfWo-Q
# user_id                                        --LnqQQ2mVdrpPt2UC8d6A
# id_y                                           lCdEv4xr5fOji8C9RfWo-Q
# name_y                                                 Groucho's Deli
# neighborhood_x
# address_x                                        9931 Rose Commons Dr
# city_x                                                   Huntersville
# state_x                                                            NC
# postal_code_x                                                   28078
# latitude_x                                                    35.4094
# longitude_x                                                  -80.8615
# stars_y                                                             4
# review_count_y                                                     33
# is_open_x                                                           0
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           lCdEv4xr5fOji8C9RfWo-Q
# name                                                   Groucho's Deli
# neighborhood_y
# address_y                                        9931 Rose Commons Dr
# city_y                                                   Huntersville
# state_y                                                            NC
# postal_code_y                                                   28078
# latitude_y                                                    35.4094
# longitude_y                                                  -80.8615
# stars                                                               4
# review_count                                                       33
# is_open_y                                                           0
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                           ...                          \
# id_x                                      ...
# name_x                                    ...
# review_count_x                            ...
# yelping_since                             ...
# useful_x                                  ...
# funny_x                                   ...
# cool_x                                    ...
# fans                                      ...
# average_stars                             ...
# compliment_hot                            ...
# compliment_more                           ...
# compliment_profile                        ...
# compliment_cute                           ...
# compliment_list                           ...
# compliment_note                           ...
# compliment_plain                          ...
# compliment_cool                           ...
# compliment_funny                          ...
# compliment_writer                         ...
# compliment_photos                         ...
# id_x                                      ...
# stars_x                                   ...
# date                                      ...
# text                                      ...
# useful_y                                  ...
# funny_y                                   ...
# cool_y                                    ...
# business_id                               ...
# user_id                                   ...
# id_y                                      ...
# name_y                                    ...
# neighborhood_x                            ...
# address_x                                 ...
# city_x                                    ...
# state_x                                   ...
# postal_code_x                             ...
# latitude_x                                ...
# longitude_x                               ...
# stars_y                                   ...
# review_count_y                            ...
# is_open_x                                 ...
# latbin_x                                  ...
# lonbin_x                                  ...
# id_y                                      ...
# name                                      ...
# neighborhood_y                            ...
# address_y                                 ...
# city_y                                    ...
# state_y                                   ...
# postal_code_y                             ...
# latitude_y                                ...
# longitude_y                               ...
# stars                                     ...
# review_count                              ...
# is_open_y                                 ...
# latbin_y                                  ...
# lonbin_y                                  ...
#
#                                                                 77976  \
# id_x                                           _RdZw-nsuyH4PHIRUXIQow
# name_x                                                              H
# review_count_x                                                      3
# yelping_since                                     2012-10-16 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                    2.33
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     1
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# ...
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     2
# compliment_plain                                                    3
# compliment_cool                                                     1
# compliment_funny                                                    1
# compliment_writer                                                   2
# compliment_photos                                                   0
# id_x                                           7mFORobnoa3Sp1jEcKFs3A
# stars_x                                                             3
# date                                              2011-08-31 00:00:00
# text                These state employees don't necessarily like t...
# useful_y                                                            1
# funny_y                                                             3
# cool_y                                                              1
# business_id                                    gWEMU-i3zBEaZwaCy79K1g
# user_id                                        _VDJ23dt2wbtXfbofOST-A
# id_y                                           gWEMU-i3zBEaZwaCy79K1g
# name_y                                     Division of Motor Vehicles
# neighborhood_x                                        University City
# address_x                                             8446 N Tryon St
# city_x                                                      Charlotte
# state_x                                                            NC
# postal_code_x                                                   28262
# latitude_x                                                    35.3034
# longitude_x                                                  -80.7508
# stars_y                                                           2.5
# review_count_y                                                      7
# is_open_x                                                           0
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           gWEMU-i3zBEaZwaCy79K1g
# name                                       Division of Motor Vehicles
# neighborhood_y                                        University City
# address_y                                             8446 N Tryon St
# city_y                                                      Charlotte
# state_y                                                            NC
# postal_code_y                                                   28262
# latitude_y                                                    35.3034
# longitude_y                                                  -80.7508
# stars                                                             2.5
# review_count                                                        7
# is_open_y                                                           0
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 77983  \
# id_x                                           _veMggEvnMCGcX4Wet36DQ
# name_x                                                            Jay
# review_count_x                                                      9
# yelping_since                                     2014-04-09 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                    2.78
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           iaXlGg9bI2QNmaa4BhpFJg
# stars_x                                                             2
# date                                              2015-09-12 00:00:00
# text                Be careful when buying from this location. A l...
# useful_y                                                            1
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    ADNBU2m0Cu-1wmeG9nkknw
# user_id                                        _veMggEvnMCGcX4Wet36DQ
# id_y                                           ADNBU2m0Cu-1wmeG9nkknw
# name_y                                                  Harris Teeter
# neighborhood_x
# address_x                                            431 Peninsula Dr
# city_x                                                       Davidson
# state_x                                                            NC
# postal_code_x                                                   28036
# latitude_x                                                     35.501
# longitude_x                                                  -80.8603
# stars_y                                                           3.5
# review_count_y                                                      8
# is_open_x                                                           1
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           ADNBU2m0Cu-1wmeG9nkknw
# name                                                    Harris Teeter
# neighborhood_y
# address_y                                            431 Peninsula Dr
# city_y                                                       Davidson
# state_y                                                            NC
# postal_code_y                                                   28036
# latitude_y                                                     35.501
# longitude_y                                                  -80.8603
# stars                                                             3.5
# review_count                                                        8
# is_open_y                                                           1
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 77984  \
# id_x                                           _xgjhgNZ5H6qQolujfDeRQ
# name_x                                                            Lee
# review_count_x                                                    372
# yelping_since                                     2007-08-28 00:00:00
# useful_x                                                         2700
# funny_x                                                          1143
# cool_x                                                           1175
# fans                                                               38
# average_stars                                                    3.07
# compliment_hot                                                     29
# compliment_more                                                     9
# compliment_profile                                                  8
# compliment_cute                                                     3
# compliment_list                                                    12
# compliment_note                                                    65
# compliment_plain                                                  153
# compliment_cool                                                    76
# compliment_funny                                                   76
# compliment_writer                                                  32
# compliment_photos                                                   6
# id_x                                           wi-kPcGXPAIEoJ7ovrWH1A
# stars_x                                                             2
# date                                              2008-02-26 00:00:00
# text                Wow, this place seriously reminds me of Chotch...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    kLVK8y8YQeRkJeld5eZbwg
# user_id                                        _xgjhgNZ5H6qQolujfDeRQ
# id_y                                           kLVK8y8YQeRkJeld5eZbwg
# name_y                                                       Macado's
# neighborhood_x
# address_x                                           8111 Concord Blvd
# city_x                                                  Concord Mills
# state_x                                                            NC
# postal_code_x                                                   28027
# latitude_x                                                    35.3692
# longitude_x                                                  -80.7221
# stars_y                                                             3
# review_count_y                                                     27
# is_open_x                                                           0
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           kLVK8y8YQeRkJeld5eZbwg
# name                                                         Macado's
# neighborhood_y
# address_y                                           8111 Concord Blvd
# city_y                                                  Concord Mills
# state_y                                                            NC
# postal_code_y                                                   28027
# latitude_y                                                    35.3692
# longitude_y                                                  -80.7221
# stars                                                               3
# review_count                                                       27
# is_open_y                                                           0
# latbin_y                                                           35
# lonbin_y                                                          -81
#
#                                                                 77985
# id_x                                           _Y8qkFCesjTp2vN3c98t6w
# name_x                                                              J
# review_count_x                                                      1
# yelping_since                                     2013-08-12 00:00:00
# useful_x                                                            0
# funny_x                                                             0
# cool_x                                                              0
# fans                                                                0
# average_stars                                                       5
# compliment_hot                                                      0
# compliment_more                                                     0
# compliment_profile                                                  0
# compliment_cute                                                     0
# compliment_list                                                     0
# compliment_note                                                     0
# compliment_plain                                                    0
# compliment_cool                                                     0
# compliment_funny                                                    0
# compliment_writer                                                   0
# compliment_photos                                                   0
# id_x                                           SF5BHFY3qAtSaXNzs2p7iA
# stars_x                                                             5
# date                                              2013-08-12 00:00:00
# text                After a tough weekend of golf, I walked in exp...
# useful_y                                                            0
# funny_y                                                             0
# cool_y                                                              0
# business_id                                    lvUndWRh72CAYAr3DmFI8Q
# user_id                                        _Y8qkFCesjTp2vN3c98t6w
# id_y                                           lvUndWRh72CAYAr3DmFI8Q
# name_y                                  HandsInMotion Massage Therapy
# neighborhood_x
# address_x                                  1096 Concord Pkwy N, Ste 3
# city_x                                                        Concord
# state_x                                                            NC
# postal_code_x                                                   28027
# latitude_x                                                    35.4299
# longitude_x                                                  -80.6083
# stars_y                                                             5
# review_count_y                                                      5
# is_open_x                                                           0
# latbin_x                                                           35
# lonbin_x                                                          -81
# id_y                                           lvUndWRh72CAYAr3DmFI8Q
# name                                    HandsInMotion Massage Therapy
# neighborhood_y
# address_y                                  1096 Concord Pkwy N, Ste 3
# city_y                                                        Concord
# state_y                                                            NC
# postal_code_y                                                   28027
# latitude_y                                                    35.4299
# longitude_y                                                  -80.6083
# stars                                                               5
# review_count                                                        5
# is_open_y                                                           0
# latbin_y                                                           35
# lonbin_y                                                          -81
#
# [57 rows x 8464 columns]

# %%
# Select from csv to json (Users)

userpoints = pd.DataFrame([user.id, user.name, user.review_count, user.average_stars]).T; # select rows

userpoints2 = userpoints.to_json(orient='records'); # convert to json

with open('users.json', 'w') as f: # save to file
    f.write(userpoints2)

# %%
# Select from csv to json (Businesses)

businesspoints = pd.DataFrame([business.id, business.name, business.review_count, business.stars]).T; # select rows

businesspoints2 = businesspoints.to_json(orient='records'); # convert to json

with open('business.json', 'w') as f: # save to file
    f.write(businesspoints2)

# %%
# Select from csv to json (Reviews)

# x = review.text.str[:50]; // to truncate comments to 50 characters

reviews = pd.DataFrame([review.business_id, review.user_id]).T; # select rows

reviews2 = reviews.to_json(orient='records'); # convert to json

with open('review.json', 'w') as f:  # save to file
    f.write(reviews2)

# %%
user.T.info
# Out:
# <bound method DataFrame.info of                                    0                       1        \
# id                  ---1lKK3aKOuomHnwAkAow  ---94vtJ_5o_nikEs6hUjg
# name                                Monera                     Joe
# review_count                           245                       2
# yelping_since          2007-06-04 00:00:00     2016-05-27 00:00:00
# useful                                  67                       0
# funny                                   22                       0
# cool                                     9                       0
# fans                                    15                       0
# average_stars                         3.97                       5
# compliment_hot                           2                       0
# compliment_more                          3                       0
# compliment_profile                       2                       0
# compliment_cute                          1                       0
# compliment_list                          0                       0
# compliment_note                          5                       0
# compliment_plain                         9                       0
# compliment_cool                          9                       0
# compliment_funny                         9                       0
# compliment_writer                        9                       0
# compliment_photos                        0                       0
#
#                                    2                       3        \
# id                  ---cu1hq55BP9DWVXXKHZg  ---fhiwiwBYrvqhpXgcWDQ
# name                                   Jeb                     Jed
# review_count                            57                       8
# yelping_since          2009-04-18 00:00:00     2011-04-20 00:00:00
# useful                                  34                       2
# funny                                   14                       3
# cool                                     0                       1
# fans                                     0                       0
# average_stars                         3.79                    2.78
# compliment_hot                           0                       0
# compliment_more                          0                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          3                       0
# compliment_plain                         2                       0
# compliment_cool                          0                       0
# compliment_funny                         0                       0
# compliment_writer                        0                       0
# compliment_photos                        0                       0
#
#                                    4                       5        \
# id                  ---PLwSf5gKdIoVnyRHgBA  ---udAKDsn0yQXmzbWQNSw
# name                                   Rae                 Carolyn
# review_count                             2                      43
# yelping_since          2015-07-31 00:00:00     2014-07-12 00:00:00
# useful                                   1                       1
# funny                                    0                       0
# cool                                     0                       0
# fans                                     0                       1
# average_stars                            4                    3.84
# compliment_hot                           0                       0
# compliment_more                          0                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          0                       0
# compliment_plain                         0                       0
# compliment_cool                          0                       0
# compliment_funny                         0                       0
# compliment_writer                        0                       0
# compliment_photos                        0                       0
#
#                                    6                       7        \
# id                  --0kuuLmuYBe3Rmu0Iycww  --0RtXvcOIE4XbErYca6Rw
# name                                 Talia                    Ryan
# review_count                            26                       2
# yelping_since          2010-03-08 00:00:00     2013-05-30 00:00:00
# useful                                  10                       0
# funny                                    2                       0
# cool                                     0                       0
# fans                                     2                       0
# average_stars                         3.48                     4.5
# compliment_hot                           0                       0
# compliment_more                          0                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          0                       0
# compliment_plain                         0                       0
# compliment_cool                          0                       0
# compliment_funny                         0                       0
# compliment_writer                        0                       0
# compliment_photos                        0                       0
#
#                                    8                       9        \
# id                  --0sXNBv6IizZXuV-nl0Aw  --0WZ5gklOfbUIodJuKfaQ
# name                                   Joe                   Scott
# review_count                             1                       7
# yelping_since          2013-01-09 00:00:00     2013-02-19 00:00:00
# useful                                   0                       0
# funny                                    0                       0
# cool                                     0                       0
# fans                                     0                       0
# average_stars                            5                    4.11
# compliment_hot                           0                       0
# compliment_more                          0                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          0                       0
# compliment_plain                         0                       0
# compliment_cool                          0                       0
# compliment_funny                         0                       0
# compliment_writer                        0                       0
# compliment_photos                        0                       0
#
#                              ...                           1183352  \
# id                           ...            __YuoYyQxvjvE5UcinU7Gg
# name                         ...                              Lola
# review_count                 ...                                 2
# yelping_since                ...               2011-10-30 00:00:00
# useful                       ...                                 1
# funny                        ...                                 0
# cool                         ...                                 0
# fans                         ...                                 0
# average_stars                ...                                 5
# compliment_hot               ...                                 0
# compliment_more              ...                                 0
# compliment_profile           ...                                 0
# compliment_cute              ...                                 0
# compliment_list              ...                                 0
# compliment_note              ...                                 0
# compliment_plain             ...                                 0
# compliment_cool              ...                                 0
# compliment_funny             ...                                 0
# compliment_writer            ...                                 0
# compliment_photos            ...                                 0
#
#                                    1183353                 1183354  \
# id                  __yYWik99gatNMlQjogAVQ  __z5mmEwnkB-BDzSD_KvmA
# name                                     M                      TR
# review_count                             2                      34
# yelping_since          2016-11-12 00:00:00     2011-07-14 00:00:00
# useful                                   0                      49
# funny                                    0                       6
# cool                                     0                       7
# fans                                     0                       2
# average_stars                            5                    2.64
# compliment_hot                           0                       0
# compliment_more                          0                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          0                       1
# compliment_plain                         0                       1
# compliment_cool                          0                       1
# compliment_funny                         0                       1
# compliment_writer                        0                       0
# compliment_photos                        0                       0
#
#                                    1183355                 1183356  \
# id                  __ZJohRr9kWepitGaKCt_Q  __ZoQKLLNHKGY4C_MQgmIA
# name                               Crystal                   Keyan
# review_count                            59                      39
# yelping_since          2013-12-01 00:00:00     2010-05-25 00:00:00
# useful                                  32                       5
# funny                                   22                       2
# cool                                    14                       1
# fans                                     9                       2
# average_stars                         4.14                     4.3
# compliment_hot                          12                       0
# compliment_more                          1                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          6                       1
# compliment_plain                        21                       3
# compliment_cool                         39                       1
# compliment_funny                        39                       1
# compliment_writer                        0                       1
# compliment_photos                        0                       0
#
#                                    1183357                 1183358  \
# id                  ___DPmKJsBF2X6ZKgAeGqg  ___fEWlObjtPaZ-pK0eq9g
# name                             Charlotte                 Nerissa
# review_count                             3                       2
# yelping_since          2014-04-07 00:00:00     2016-05-09 00:00:00
# useful                                   0                       0
# funny                                    0                       0
# cool                                     1                       0
# fans                                     0                       0
# average_stars                         3.33                       5
# compliment_hot                           0                       0
# compliment_more                          0                       0
# compliment_profile                       0                       0
# compliment_cute                          0                       0
# compliment_list                          0                       0
# compliment_note                          0                       0
# compliment_plain                         0                       0
# compliment_cool                          0                       0
# compliment_funny                         0                       0
# compliment_writer                        0                       0
# compliment_photos                        0                       0
#
#                                    1183359                 1183360  \
# id                  ___I9ZYdYGkZ6dMYxwJEIQ  ___MTsBloH4jvybJ5DrTYw
# name                                   Jim                      TJ
# review_count                           150                      10
# yelping_since          2011-08-17 00:00:00     2011-03-25 00:00:00
# useful                                 131                       3
# funny                                   44                       0
# cool                                    85                       0
# fans                                     9                       0
# average_stars                         3.96                     4.9
# compliment_hot                           1                       0
# compliment_more                          3                       0
# compliment_profile                       1                       0
# compliment_cute                          1                       0
# compliment_list                          0                       0
# compliment_note                          6                       0
# compliment_plain                         8                       1
# compliment_cool                          2                       0
# compliment_funny                         2                       0
# compliment_writer                        0                       0
# compliment_photos                        1                       0
#
#                                    1183361
# id                  ___QCazm0YrHLd3uNUPYMA
# name                                  Mike
# review_count                             5
# yelping_since          2014-07-31 00:00:00
# useful                                  10
# funny                                    3
# cool                                     1
# fans                                     0
# average_stars                            5
# compliment_hot                           0
# compliment_more                          0
# compliment_profile                       0
# compliment_cute                          0
# compliment_list                          0
# compliment_note                          0
# compliment_plain                         0
# compliment_cool                          0
# compliment_funny                         0
# compliment_writer                        0
# compliment_photos                        0
#
# [20 rows x 1183362 columns]>
